# %%
import pandas as pd

# %%
apple = pd.read_csv("https://raw.githubusercontent.com/ActiveConclusion/COVID19_mobility/master/apple_reports/apple_mobility_report.csv")
print(apple.columns)
apple.head()
# Out:
# Index(['country', 'sub-region', 'subregion_and_city', 'geo_type', 'date',
#        'driving', 'transit', 'walking'],
#       dtype='object')
#    country sub-region subregion_and_city        geo_type        date  driving  \
# 0  Albania      Total              Total  country/region  2020-01-13     0.00
# 1  Albania      Total              Total  country/region  2020-01-14    -4.70
# 2  Albania      Total              Total  country/region  2020-01-15     1.43
# 3  Albania      Total              Total  country/region  2020-01-16    -2.80
# 4  Albania      Total              Total  country/region  2020-01-17     3.55
#
#    transit  walking
# 0      NaN     0.00
# 1      NaN     0.68
# 2      NaN    -1.07
# 3      NaN    -1.54
# 4      NaN     0.85

# %%
print("Malaysia" in apple['country'].unique())
malaysia = apple.loc[(apple['country']=='Malaysia')]
malaysia.describe(include="all")
# Out:
#          country    sub-region subregion_and_city geo_type        date  \
# count       1710          1710               1710     1710        1710
# unique         1             3                  3        2         570
# top     Malaysia  Kuala Lumpur       Kuala Lumpur     city  2021-01-12
# freq        1710           570                570     1140           3
# mean         NaN           NaN                NaN      NaN         NaN
# std          NaN           NaN                NaN      NaN         NaN
# min          NaN           NaN                NaN      NaN         NaN
# 25%          NaN           NaN                NaN      NaN         NaN
# 50%          NaN           NaN                NaN      NaN         NaN
# 75%          NaN           NaN                NaN      NaN         NaN
# max          NaN           NaN                NaN      NaN         NaN
#
#             driving  transit      walking
# count   1710.000000      0.0  1140.000000
# unique          NaN      NaN          NaN
# top             NaN      NaN          NaN
# freq            NaN      NaN          NaN
# mean     -17.820485      NaN   -40.709368
# std       28.253315      NaN    22.685113
# min      -75.640000      NaN   -87.090000
# 25%      -39.667500      NaN   -58.912500
# 50%      -20.055000      NaN   -42.160000
# 75%        0.450000      NaN   -26.920000
# max      112.270000      NaN    55.330000

# %%
print(malaysia['sub-region'].unique())
appledata = malaysia[['date', 'sub-region', 'driving', 'transit', 'walking']]
appledata.rename(columns={'sub-region':'state'}, inplace=True)
appledata.describe(include="all")
# Out:
# ['Johor' 'Kuala Lumpur' 'Total']
# C:\Users\DELL\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
appledata.to_csv("apple-mobility-data-malaysia.csv", index=False)
